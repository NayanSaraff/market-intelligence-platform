# %% [markdown]
# # 03 — ETS (Holt-Winters) Modeling
#
# This notebook runs the ETS pipeline on all selected stocks using `src/models/ets_model.py`.
# It saves model metrics, rolling predictions, and 5-day forecasts to the `outputs/` folders.

# %%
from pathlib import Path
import os
import warnings
warnings.filterwarnings('ignore')

if Path.cwd().name == 'notebooks':
    os.chdir(Path.cwd().parent)

ROOT = Path.cwd()
PROC_DIR = ROOT / 'data' / 'processed'
REPORT_DIR = ROOT / 'outputs' / 'reports'
PRED_DIR = ROOT / 'outputs' / 'predictions'
CHART_DIR = ROOT / 'outputs' / 'charts' / 'ets'
for directory in [REPORT_DIR, PRED_DIR, CHART_DIR]:
    directory.mkdir(parents=True, exist_ok=True)

import pandas as pd
import matplotlib.pyplot as plt
from src.data.preprocessor import SELECTED, NAMES
from src.models.ets_model import ETSForecaster

pd.set_option('display.max_columns', 200)
pd.set_option('display.width', 140)

def load_close_series(file_path: Path) -> pd.Series:
    frame = pd.read_csv(file_path, index_col=0, parse_dates=True)
    if 'Close' not in frame.columns:
        raise ValueError(f'Missing Close column in {file_path}')
    series = frame['Close'].dropna().sort_index()
    series.name = file_path.stem
    return series

metrics_rows = []
forecast_rows = []
actual_rows = []

for ticker in SELECTED:
    try:
        train_path = PROC_DIR / f'{ticker}_train_full.csv'
        test_path = PROC_DIR / f'{ticker}_test_full.csv'
        if not train_path.exists() or not test_path.exists():
            print(f'Skipping {ticker}: processed files not found')
            continue

        train_series = load_close_series(train_path)
        test_series = load_close_series(test_path)

        model = ETSForecaster(ticker=ticker, name=NAMES.get(ticker, ticker), season=5)
        model.run(train_series, test_series)

        metrics_rows.append(model.metrics)
        forecast_rows.append(model.forecast_5d.reset_index())
        actual_rows.append(pd.DataFrame({
            'Date': test_series.index,
            'Ticker': ticker,
            'Company': NAMES.get(ticker, ticker),
            'Actual': test_series.values,
            'Predicted': model.predictions.values,
            'Model': model.metrics['Model'],
        }))
        print(f"{ticker}: RMSE={model.metrics['RMSE']:.4f}  DA={model.metrics['DA_%']:.2f}%  config={model.best_label}")
    except Exception as e:
        print(f"ERROR — {ticker}: {type(e).__name__}: {e}")
        continue

metrics_df = pd.DataFrame(metrics_rows).sort_values(['RMSE', 'MAE']).reset_index(drop=True)
forecasts_df = pd.concat(forecast_rows, ignore_index=True) if forecast_rows else pd.DataFrame()
actual_df = pd.concat(actual_rows, ignore_index=True) if actual_rows else pd.DataFrame()

metrics_df.to_csv(REPORT_DIR / 'ets_metrics.csv', index=False)
forecasts_df.to_csv(PRED_DIR / 'ets_5day_forecasts.csv', index=False)
actual_df.to_csv(PRED_DIR / 'ets_actual_vs_predicted.csv', index=False)

if not metrics_df.empty:
    fig, ax = plt.subplots(figsize=(12, 5))
    plot_df = metrics_df[['Ticker', 'RMSE']].sort_values('RMSE')
    ax.bar(plot_df['Ticker'], plot_df['RMSE'], color='#ff7f0e')
    ax.set_title('ETS RMSE by Stock')
    ax.set_ylabel('RMSE')
    ax.set_xlabel('Ticker')
    ax.tick_params(axis='x', rotation=45)
    fig.tight_layout()
    fig.savefig(CHART_DIR / 'ets_rmse_by_ticker.png', dpi=150, bbox_inches='tight')
    plt.show()

display(metrics_df.head(10))
print(f'Saved: {REPORT_DIR / "ets_metrics.csv"}')
print(f'Saved: {PRED_DIR / "ets_5day_forecasts.csv"}')
print(f'Saved: {PRED_DIR / "ets_actual_vs_predicted.csv"}')
# Out:
# 09:43:15 | INFO |   [ITC.NS] ETS model selection ...
# 09:43:19 | INFO |   [ITC.NS] Best ETS: Holt-Additive  AIC=3715.37
# 09:43:31 | INFO |   [ITC.NS] ETS rolling prediction complete
# 09:43:31 | INFO |   [ITC.NS] ETS 5-day forecast: [484.05 484.28 484.51 484.74 484.97]
# 09:43:31 | INFO |   [SUNPHARMA.NS] ETS model selection ...
# ITC.NS: RMSE=5.9500  DA=44.53%  config=Holt-Additive
# 09:43:35 | INFO |   [SUNPHARMA.NS] Best ETS: Holt-Additive  AIC=6100.07
# 09:43:47 | INFO |   [SUNPHARMA.NS] ETS rolling prediction complete
# 09:43:47 | INFO |   [SUNPHARMA.NS] ETS 5-day forecast: [1382.2  1382.83 1383.45 1384.08 1384.7 ]
# 09:43:47 | INFO |   [TATAMOTORS.NS] ETS model selection ...
# SUNPHARMA.NS: RMSE=26.0538  DA=46.09%  config=Holt-Additive
# 09:43:52 | INFO |   [TATAMOTORS.NS] Best ETS: Holt-Winters-Mul  AIC=5465.54
# 09:44:52 | INFO |   [TATAMOTORS.NS] ETS rolling prediction complete
# 09:44:53 | INFO |   [TATAMOTORS.NS] ETS 5-day forecast: [508.12 507.51 507.75 510.96 509.98]
# 09:44:53 | INFO |   [ICICIBANK.NS] ETS model selection ...
# TATAMOTORS.NS: RMSE=15.4171  DA=50.78%  config=Holt-Winters-Mul
# 09:44:57 | INFO |   [ICICIBANK.NS] Best ETS: Holt-Additive  AIC=6139.52
# 09:45:08 | INFO |   [ICICIBANK.NS] ETS rolling prediction complete
# 09:45:08 | INFO |   [ICICIBANK.NS] ETS 5-day forecast: [1052.31 1052.65 1052.99 1053.32 1053.66]
# 09:45:08 | INFO |   [INFY.NS] ETS model selection ...
# ICICIBANK.NS: RMSE=19.8303  DA=50.00%  config=Holt-Additive
# 09:45:13 | INFO |   [INFY.NS] Best ETS: Holt-Additive  AIC=6541.75
# 09:45:24 | INFO |   [INFY.NS] ETS rolling prediction complete
# 09:45:25 | INFO |   [INFY.NS] ETS 5-day forecast: [2390.12 2390.96 2391.79 2392.62 2393.45]
# 09:45:25 | INFO |   [MARUTI.NS] ETS model selection ...
# INFY.NS: RMSE=42.7348  DA=52.34%  config=Holt-Additive
# 09:45:29 | INFO |   [MARUTI.NS] Best ETS: Holt-Additive  AIC=10746.71
# 09:45:41 | INFO |   [MARUTI.NS] ETS rolling prediction complete
# 09:45:41 | INFO |   [MARUTI.NS] ETS 5-day forecast: [11445.06 11448.68 11452.31 11455.93 11459.55]
# 09:45:41 | INFO |   [DRREDDY.NS] ETS model selection ...
# MARUTI.NS: RMSE=231.6079  DA=40.62%  config=Holt-Additive
# 09:45:45 | INFO |   [DRREDDY.NS] Best ETS: Holt-Additive  AIC=9921.57
# 09:45:59 | INFO |   [DRREDDY.NS] ETS rolling prediction complete
# 09:45:59 | INFO |   [DRREDDY.NS] ETS 5-day forecast: [5963.04 5964.35 5965.66 5966.97 5968.28]
# 09:45:59 | INFO |   [HDFCBANK.NS] ETS model selection ...
# DRREDDY.NS: RMSE=99.5242  DA=44.53%  config=Holt-Additive
# 09:46:04 | INFO |   [HDFCBANK.NS] Best ETS: Holt-Additive  AIC=6623.36
# 09:46:14 | INFO |   [HDFCBANK.NS] ETS rolling prediction complete
# 09:46:15 | INFO |   [HDFCBANK.NS] ETS 5-day forecast: [1793.95 1794.25 1794.54 1794.83 1795.13]
# HDFCBANK.NS: RMSE=27.5157  DA=51.56%  config=Holt-Additive
#           Ticker      Company                  Model               Config       AIC      RMSE       MAE  MAPE_%   DA_%      R2
# 0         ITC.NS          ITC     ETS(Holt-Additive)  ('add', None, None)   3715.37    5.9500    4.6300  1.0884  44.53  0.9782
# 1  TATAMOTORS.NS  Tata Motors  ETS(Holt-Winters-Mul)    ('add', 'mul', 5)   5465.54   15.4171   11.8879  2.2586  50.78  0.8955
# 2   ICICIBANK.NS   ICICI Bank     ETS(Holt-Additive)  ('add', None, None)   6139.52   19.8303   15.7687  1.4024  50.00  0.9006
# 3   SUNPHARMA.NS   Sun Pharma     ETS(Holt-Additive)  ('add', None, None)   6100.07   26.0538   20.6502  1.5083  46.09  0.9206
# 4    HDFCBANK.NS    HDFC Bank     ETS(Holt-Additive)  ('add', None, None)   6623.36   27.5157   20.7165  1.1514  51.56  0.8461
# 5        INFY.NS      Infosys     ETS(Holt-Additive)  ('add', None, None)   6541.75   42.7348   33.3957  1.2249  52.34  0.8721
# 6     DRREDDY.NS   Dr Reddy's     ETS(Holt-Additive)  ('add', None, None)   9921.57   99.5242   77.5981  1.3774  44.53  0.7788
# 7      MARUTI.NS       Maruti     ETS(Holt-Additive)  ('add', None, None)  10746.71  231.6079  179.4485  1.5200  40.62  0.8231
# Saved: d:\PROJECTS\IIT GUWAHTI- CAPSTONE\StockGro_Capstone\outputs\reports\ets_metrics.csv
# Saved: d:\PROJECTS\IIT GUWAHTI- CAPSTONE\StockGro_Capstone\outputs\predictions\ets_5day_forecasts.csv
# Saved: d:\PROJECTS\IIT GUWAHTI- CAPSTONE\StockGro_Capstone\outputs\predictions\ets_actual_vs_predicted.csv
